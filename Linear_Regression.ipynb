# %% [markdown]
# <a href="https://colab.research.google.com/github/kumardigamberjha/Projects/blob/master/Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('Car_Purchasing_Data.csv')
df
# Out:
#        Customer Name                                    Customer e-mail  \
# 0      Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1      Harlan Barnes                                eu.dolor@diam.co.uk
# 2    Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3    Jade Cunningham                            malesuada@dignissim.com
# 4       Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
# ..               ...                                                ...
# 495           Walter                                ligula@Cumsociis.ca
# 496            Vanna                 Cum.sociis.natoque@Sedmolestie.edu
# 497            Pearl                      penatibus.et@massanonante.com
# 498             Nell                  Quisque.varius@arcuVivamussit.net
# 499            Marla                          Camaron.marla@hotmail.com
#
#     Country  Gender  Age  Annual Salary  Credit Card Debt    Net Worth  \
# ...

# %%
X = df.iloc[:, :-1]
X
# Out:
#        Customer Name                                    Customer e-mail  \
# 0      Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1      Harlan Barnes                                eu.dolor@diam.co.uk
# 2    Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3    Jade Cunningham                            malesuada@dignissim.com
# 4       Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
# ..               ...                                                ...
# 495           Walter                                ligula@Cumsociis.ca
# 496            Vanna                 Cum.sociis.natoque@Sedmolestie.edu
# 497            Pearl                      penatibus.et@massanonante.com
# 498             Nell                  Quisque.varius@arcuVivamussit.net
# 499            Marla                          Camaron.marla@hotmail.com
#
#     Country  Gender  Age  Annual Salary  Credit Card Debt    Net Worth
# ...

# %%
Y = df.iloc[:, -1]
Y
# Out:
# 0      35321.45877
# 1      45115.52566
# 2      42925.70921
# 3      67422.36313
# 4      55915.46248
#           ...
# 495    48901.44342
# 496    31491.41457
# 497    64147.28888
# 498    45442.15353
# 499    45107.22566
# Name: Car Purchase Amount, Length: 500, dtype: float64

# %%
reg = LinearRegression()

# %%
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder()

encoder.fit(X)
X = encoder.transform(X)

X_train, X_test, Y_Train, y_test = train_test_split(X, Y, test_size=0.2, random_state=22)

# %%
reg.fit(X_train, Y_Train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error

# %%
y_test_reshaped = y_test.values.reshape(-1, 1)

# Make predictions on the test data
y_pred = reg.predict(X_test)

# %%
y_pred
# Out:
# array([44833.87482609, 43706.84665826, 42177.26790486, 42177.26790486,
#        39409.92416743, 42640.00814525, 48387.59080239, 45434.35187405,
#        45434.35187405, 42177.76602052, 47715.53007689, 42177.76602052,
#        35893.03476893, 38160.39277817, 39212.24266378, 50083.00797261,
#        52071.5772472 , 53261.97695133, 42177.26790486, 43889.53953451,
#        39905.36133475, 39409.92416743, 40725.45091854, 46709.5297715 ,
#        42144.7123208 , 42144.7123208 , 42640.00814525, 48387.59080239,
#        47138.05941313, 38606.09726798, 43889.53953451, 42144.7123208 ,
#        39212.24266378, 46692.74852028, 47715.53007689, 44599.94612227,
#        47138.05941313, 48387.59080239, 48390.75896835, 43958.43081111,
#        48390.75896835, 43427.29740978, 54511.50834059, 42457.315269  ,
#        43427.29740978, 49133.9623902 , 52071.5772472 , 50950.69654062,
#        48387.59080239, 44599.94612227, 48387.59080239, 47959.06116076,
# ...

# %%
mse = mean_squared_error(y_test_reshaped, y_pred)

# %%
mse
# Out:
# 94022508.71227024

# %%
print(reg.score(X_test, y_test))
# Out:
# 0.1867210678798713

# %%
import matplotlib.pyplot as plt

# %%
reg.score(X_train,Y_Train)
# Out:
# 0.9999999999750403
